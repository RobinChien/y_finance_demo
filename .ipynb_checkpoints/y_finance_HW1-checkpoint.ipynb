# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get data by yfinance

# %%
# Get the TASLA stock from 2021/10/1 to 2022/10/1
tsla_df = yf.download("TSLA", start='2021-10-01', end='2022-10-01')
tsla_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
# ...                ...         ...         ...         ...         ...
# 2022-09-26  271.829987  284.089996  270.309998  276.010010  276.010010
# 2022-09-27  283.839996  288.670013  277.510010  282.940002  282.940002
# 2022-09-28  283.079987  289.000000  277.570007  287.809998  287.809998
# 2022-09-29  282.760010  283.649994  265.779999  268.209991  268.209991
# 2022-09-30  266.149994  275.570007  262.470001  265.250000  265.250000
#
#               Volume
# Date
# 2021-09-30  53868000
# 2021-10-01  51094200
# 2021-10-04  91449900
# 2021-10-05  55297800
# 2021-10-06  43898400
# ...              ...
# 2022-09-26  58076900
# 2022-09-27  61925200
# 2022-09-28  54664800
# 2022-09-29  77620600
# 2022-09-30  67517800
#
# [253 rows x 6 columns]

# %%
# Summary Stats for TASLA stocks
tsla_df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000
# mean   300.160579  307.529776  292.136100  299.728129  299.728129
# std     46.119428   46.754702   44.669261   45.772898   45.772898
# min    207.949997  217.973328  206.856674  209.386673  209.386673
# 25%    266.513336  273.266663  260.799988  266.923340  266.923340
# 50%    298.500000  303.709991  289.130005  296.666656  296.666656
# 75%    335.600006  344.950012  327.510010  336.336670  336.336670
# max    411.470001  414.496674  405.666656  409.970001  409.970001
#
#              Volume
# count  2.530000e+02
# mean   8.052881e+07
# std    2.545462e+07
# min    3.504270e+07
# 25%    6.255570e+07
# 50%    7.695630e+07
# 75%    9.347310e+07
# max    1.885563e+08

# %%
# Historical view of the closing price of stock
tsla_df['Adj Close'].plot(legend=True,figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Data Preprocessing

# %%
# Calculation of moving averages for 5 days of stocks
ma = 5
column_name = "MA for %s days" %(str(ma))    
tsla_df[column_name] = tsla_df['Adj Close'].rolling(window=ma).mean()
tsla_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
# ...                ...         ...         ...         ...         ...
# 2022-09-26  271.829987  284.089996  270.309998  276.010010  276.010010
# 2022-09-27  283.839996  288.670013  277.510010  282.940002  282.940002
# 2022-09-28  283.079987  289.000000  277.570007  287.809998  287.809998
# 2022-09-29  282.760010  283.649994  265.779999  268.209991  268.209991
# 2022-09-30  266.149994  275.570007  262.470001  265.250000  265.250000
#
#               Volume  MA for 5 days
# Date
# 2021-09-30  53868000            NaN
# 2021-10-01  51094200            NaN
# 2021-10-04  91449900            NaN
# 2021-10-05  55297800            NaN
# 2021-10-06  43898400     259.704669
# ...              ...            ...
# 2022-09-26  58076900     289.891998
# 2022-09-27  61925200     284.733997
# 2022-09-28  54664800     282.135999
# 2022-09-29  77620600     278.059998
# 2022-09-30  67517800     276.044000
#
# [253 rows x 7 columns]

# %%
tsla_df=tsla_df.rename(columns = {'Adj Close':'MA for 1 days'})
tsla_df
# Out:
#                   Open        High         Low       Close  MA for 1 days  \
# Date
# 2021-09-30  260.333344  263.043335  258.333344  258.493347     258.493347
# 2021-10-01  259.466675  260.260010  254.529999  258.406677     258.406677
# 2021-10-04  265.500000  268.989990  258.706665  260.510010     260.510010
# 2021-10-05  261.600006  265.769989  258.066681  260.196655     260.196655
# 2021-10-06  258.733337  262.220001  257.739990  260.916656     260.916656
# ...                ...         ...         ...         ...            ...
# 2022-09-26  271.829987  284.089996  270.309998  276.010010     276.010010
# 2022-09-27  283.839996  288.670013  277.510010  282.940002     282.940002
# 2022-09-28  283.079987  289.000000  277.570007  287.809998     287.809998
# 2022-09-29  282.760010  283.649994  265.779999  268.209991     268.209991
# 2022-09-30  266.149994  275.570007  262.470001  265.250000     265.250000
#
#               Volume  MA for 5 days
# Date
# 2021-09-30  53868000            NaN
# 2021-10-01  51094200            NaN
# 2021-10-04  91449900            NaN
# 2021-10-05  55297800            NaN
# 2021-10-06  43898400     259.704669
# ...              ...            ...
# 2022-09-26  58076900     289.891998
# 2022-09-27  61925200     284.733997
# 2022-09-28  54664800     282.135999
# 2022-09-29  77620600     278.059998
# 2022-09-30  67517800     276.044000
#
# [253 rows x 7 columns]

# %% [markdown]
# ## Visualization

# %%
colors = {'red': '#ff207c', 'grey': '#42535b', 'blue': '#207cff', 'orange': '#ffa320', 'green': '#00ec8b'}

# %%
mov_avg = {
        'MA (1)': {'Range': 1, 'Color': colors['blue']},
        'MA (5)': {'Range': 5, 'Color': colors['orange']}
    }

date = tsla_df.index

for ma, ma_info in mov_avg.items():
    column_name = "MA for %s days" %(str(ma_info['Range']))    
    plt.plot(
        date, tsla_df[column_name], 
        color=ma_info['Color'], label=ma, linewidth=2
    )

# %%
vol = tsla_df['Volume']

vol_plot = plt.bar(date, vol, width=15, color='darkgrey')
vol_plot
# Out:
# <BarContainer object of 253 artists>

# %%
# Combine close price with volume in fix size
plt.rc('figure', figsize=(15, 10))
    
fig, axes = plt.subplots(
    2, 1, gridspec_kw={'height_ratios': [3, 1]}
)
fig.tight_layout(pad=3)

plot_close_price = axes[0]
for ma, ma_info in mov_avg.items():
    column_name = "MA for %s days" %(str(ma_info['Range']))    
    plot_close_price.plot(
        date, tsla_df[column_name], 
        color=ma_info['Color'], label=ma, linewidth=2
    )

plot_vol = axes[1]
plot_vol.bar(date, vol, width=15, color='darkgrey')
# Out:
# <BarContainer object of 253 artists>
